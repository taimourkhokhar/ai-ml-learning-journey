# %%
import torch
import torch.nn as nn

class Model(nn.Module):
  def __init__(self,num_features):
    super().__init__()
    self.network=nn.Sequential(
        nn.Linear(num_features,3),
        nn.ReLU(),
        nn.Linear(3,1),
        nn.Sigmoid()
    )

  def forward(self,features):
    out=self.network(features)
    return out

# %%
features=torch.rand(10,5)
model=Model(features.shape[1])
model(features)
# Out:
# tensor([[0.4969],
#         [0.4860],
#         [0.5041],
#         [0.4867],
#         [0.4894],
#         [0.4639],
#         [0.4867],
#         [0.4811],
#         [0.4917],
#         [0.4665]], grad_fn=<SigmoidBackward0>)

# %%
model.state_dict()
# Out:
# OrderedDict([('network.0.weight',
#               tensor([[ 0.1924,  0.0736,  0.3091, -0.2307, -0.3803],
#                       [ 0.1037,  0.2376, -0.3323,  0.0895,  0.1359],
#                       [-0.1692,  0.2887, -0.2787,  0.0238,  0.0562]])),
#              ('network.0.bias', tensor([-0.1868,  0.4320, -0.0873])),
#              ('network.2.weight', tensor([[-0.2765,  0.4897, -0.3756]])),
#              ('network.2.bias', tensor([-0.3178]))])

# %%
# !pip install torchinfo

# %%
from torchinfo import summary
summary(model,input_size=(10,5))
