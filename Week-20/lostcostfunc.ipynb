# %%
import numpy as np
y_predicted=np.array([1,1,0,0,1])
y_true=np.array([0.30,0.7,1,0,0.5])

# %%
def mae(y_true,y_predicted):
  total_error=0
  for yt,yp in zip(y_true,y_predicted):
    total_error+=abs(yt-yp)
  print(total_error)
  mae=total_error/len(y_true)
  return mae

# %%
mae(y_true,y_predicted)
# Out:
# 2.5
# np.float64(0.5)

# %%
np.mean(np.abs(y_predicted-y_true))
# Out:
# np.float64(0.5)

# %%
np.log([0.000000000000001])
# Out:
# array([-34.53877639])

# %%
eplison=1e-15

# %%
y_predicted_new=[max(i,eplison) for i in y_predicted]
y_predicted_new
# Out:
# [np.int64(1), np.int64(1), 1e-15, 1e-15, np.int64(1)]

# %%
y_predicted_new=[min(i,1-eplison) for i in y_predicted]
y_predicted_new
# Out:
# [0.999999999999999,
#  0.999999999999999,
#  np.int64(0),
#  np.int64(0),
#  0.999999999999999]

# %%
-np.mean(y_true*np.log(y_predicted_new)+(1-y_true)*np.log(1-y_predicted_new))
# Out:
# C:\Users\taimo\AppData\Local\Temp\ipykernel_14576\2945582866.py:1: RuntimeWarning: divide by zero encountered in log
#   -np.mean(y_true*np.log(y_predicted_new)+(1-y_true)*np.log(y_predicted_new))
# C:\Users\taimo\AppData\Local\Temp\ipykernel_14576\2945582866.py:1: RuntimeWarning: invalid value encountered in multiply
#   -np.mean(y_true*np.log(y_predicted_new)+(1-y_true)*np.log(y_predicted_new))
# np.float64(nan)

# %%
def log_loss(y_true,y_predicted):
  eplison=1e-15
  y_predicted_new=[max(i,eplison) for i in y_predicted]
  y_predicted_new=[min(i,1-eplison) for i in y_predicted_new]
  y_predicted_new=np.array(y_predicted_new)
  return -np.mean(y_true*np.log(y_predicted_new)+(1-y_true)*np.log(1-y_predicted_new))

# %%
log_loss(y_true,y_predicted)
# Out:
# np.float64(17.2696280766844)

# %%
import numpy as np
y_predicted=np.array([1,1,0,0,1])
y_true=np.array([0.30,0.7,1,0,0.5])

# %%
def mse(y_true,y_predicted):
  total_error=0
  for yt,yp in zip(y_true,y_predicted):
    total_error+=abs((yt-yp)*(yt-yp))
  print(total_error)
  mse=total_error/len(y_true)
  return mse

# %%
mse(y_true,y_predicted)
# Out:
# 1.83
# np.float64(0.366)

# %%
np.mean(np.abs((y_predicted-y_true)*(y_predicted-y_true)))
# Out:
# np.float64(0.366)
