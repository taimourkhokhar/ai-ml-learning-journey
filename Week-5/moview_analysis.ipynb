# %%
import pandas as pd
df=pd.read_csv("D:/movies.csv")
# df.head(7)#print head 
# df.tail(3)#print rows from tail
# df.sample(2)#it will print randomly 2
# df[2:6]
# df.shape
# df["budget"]
# type(df.budget)
# df.budget
df.budget.min()
df.budget.max()
df.budget.mean()
df[df.genres=="Horror"]
# Out:
#       index    budget  genres  \
# 1011   1011         0  Horror
# 1160   1160  40000000  Horror
# 1242   1242  40000000  Horror
# 1378   1378   1800000  Horror
# 1396   1396  10700000  Horror
# ...     ...       ...     ...
# 4682   4682  13000000  Horror
# 4684   4684         0  Horror
# 4765   4765         0  Horror
# 4771   4771         0  Horror
# 4791   4791        13  Horror
#
#                                                homepage      id  \
# 1011                                                NaN   53953
# 1160              http://www.warnerbros.com/conjuring-2  259693
# 1242                     http://www.thereapingmovie.com    1683
# 1378                                                NaN     377
# 1396                                                NaN     609
# ...                                                 ...     ...
# 4682                                                NaN   69270
# 4684                                                NaN  402515
# ...

# %%
# import csv

# with open("D:/movies.csv", 'r', newline='', encoding="utf-8") as f:
#     full_data = list(csv.reader(f))
    
#     if full_data:
#         header = full_data[0]  
#         data = full_data[1:]    

# print("Header:", header)
# print("Total Movies Found:", len(data))
# print("Sample Data:", data[:3])
