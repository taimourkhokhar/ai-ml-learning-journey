# %%
import spacy
nlp=spacy.blank("en")
doc=nlp("Dr. Strange loves pav bhaji of mumbai as it cost only 2$ per plate.")
for token in doc:
  print(token)
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\taimo\AppData\Roaming\Python\Python311\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\taimo\AppData\Roaming\Python\Python311\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\taimo\AppData\Roaming\Python\Python311\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "C:\Users\taimo\AppData\Roaming\Python\Python311\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Users\taimo\AppData\Local\Programs\Python\Python311\Lib\asyncio\base_events.py", line 607, in run_forever
#     self._run_once()
#   File "c:\Users\taimo\AppData\Local\Programs\Python\Python311\Lib\asyncio\base_events.py", line 1922, in _run_once
#     handle._run()
#   File "c:\Users\taimo\AppData\Local\Programs\Python\Python311\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\taimo\AppData\Roaming\Python\Python311\site-packages\ipykernel\kernelbase.py", line 621, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "C:\Users\taimo\AppData\Roaming\Python\Python311\site-packages\ipykernel\kernelbase.py", line 478, in dispatch_shell
#     await result
#   File "C:\Users\taimo\AppData\Roaming\Python\Python311\site-packages\ipykernel\ipkernel.py", line 372, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\taimo\AppData\Roaming\Python\Python311\site-packages\ipykernel\kernelbase.py", line 834, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\taimo\AppData\Roaming\Python\Python311\site-packages\ipykernel\ipkernel.py", line 464, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\taimo\AppData\Roaming\Python\Python311\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\taimo\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py", line 3123, in run_cell
#     result = self._run_cell(
#   File "C:\Users\taimo\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py", line 3178, in _run_cell
#     result = runner(coro)
#   File "C:\Users\taimo\AppData\Roaming\Python\Python311\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\taimo\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py", line 3400, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\taimo\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py", line 3641, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\taimo\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py", line 3701, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\taimo\AppData\Local\Temp\ipykernel_13640\1172401729.py", line 1, in <module>
#     import spacy
#   File "c:\Users\taimo\AppData\Local\Programs\Python\Python311\Lib\site-packages\spacy\__init__.py", line 6, in <module>
#     from .errors import setup_default_warnings
#   File "c:\Users\taimo\AppData\Local\Programs\Python\Python311\Lib\site-packages\spacy\errors.py", line 3, in <module>
#     from .compat import Literal
#   File "c:\Users\taimo\AppData\Local\Programs\Python\Python311\Lib\site-packages\spacy\compat.py", line 5, in <module>
#     from thinc.util import copy_array
#   File "c:\Users\taimo\AppData\Local\Programs\Python\Python311\Lib\site-packages\thinc\__init__.py", line 5, in <module>
#     from .config import registry
#   File "c:\Users\taimo\AppData\Local\Programs\Python\Python311\Lib\site-packages\thinc\config.py", line 5, in <module>
#     from .types import Decorator
#   File "c:\Users\taimo\AppData\Local\Programs\Python\Python311\Lib\site-packages\thinc\types.py", line 25, in <module>
#     from .compat import cupy, has_cupy
#   File "c:\Users\taimo\AppData\Local\Programs\Python\Python311\Lib\site-packages\thinc\compat.py", line 35, in <module>
#     import torch
#   File "c:\Users\taimo\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\__init__.py", line 1382, in <module>
#     from .functional import *  # noqa: F403
#   File "c:\Users\taimo\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\functional.py", line 7, in <module>
#     import torch.nn.functional as F
#   File "c:\Users\taimo\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\__init__.py", line 1, in <module>
#     from .modules import *  # noqa: F403
#   File "c:\Users\taimo\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\__init__.py", line 35, in <module>
#     from .transformer import TransformerEncoder, TransformerDecoder, \
#   File "c:\Users\taimo\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\transformer.py", line 20, in <module>
#     device: torch.device = torch.device(torch._C._get_default_device()),  # torch.device('cpu'),
# c:\Users\taimo\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\transformer.py:20: UserWarning: Failed to initialize NumPy: _ARRAY_API not found (Triggered internally at ..\torch\csrc\utils\tensor_numpy.cpp:84.)
#   device: torch.device = torch.device(torch._C._get_default_device()),  # torch.device('cpu'),
# Dr.
# Strange
# loves
# pav
# bhaji
# of
# mumbai
# as
# it
# cost
# only
# 2
# $
# per
# plate
# .

# %%
doc[0]
# Out:
# Dr.

# %%
nlp=spacy.blank("en")
doc=nlp("Let's go to N.Y.!")
for token in doc:
  print(token)
# Out:
# Let
# 's
# go
# to
# N.Y.
# !

# %%
type(nlp)
# Out:
# spacy.lang.en.English

# %%
span=doc[1:5]
type(span)
# Out:
# spacy.tokens.span.Span

# %%
doc=nlp("Tony gave two $ to peter.")

# %%
tokern0=doc[0]
tokern0
# Out:
# Tony

# %%
dir(tokern0)
# Out:
# ['_',
#  '__bytes__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__pyx_vtable__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  'ancestors',
#  'check_flag',
#  'children',
#  'cluster',
#  'conjuncts',
#  'dep',
#  'dep_',
#  'doc',
#  'ent_id',
#  'ent_id_',
#  'ent_iob',
#  'ent_iob_',
#  'ent_kb_id',
#  'ent_kb_id_',
#  'ent_type',
#  'ent_type_',
#  'get_extension',
#  'has_dep',
#  'has_extension',
#  'has_head',
#  'has_morph',
#  'has_vector',
#  'head',
#  'i',
#  'idx',
#  'iob_strings',
#  'is_alpha',
#  'is_ancestor',
#  'is_ascii',
#  'is_bracket',
#  'is_currency',
#  'is_digit',
#  'is_left_punct',
#  'is_lower',
#  'is_oov',
#  'is_punct',
#  'is_quote',
#  'is_right_punct',
#  'is_sent_end',
#  'is_sent_start',
#  'is_space',
#  'is_stop',
#  'is_title',
#  'is_upper',
#  'lang',
#  'lang_',
#  'left_edge',
#  'lefts',
#  'lemma',
#  'lemma_',
#  'lex',
#  'lex_id',
#  'like_email',
#  'like_num',
#  'like_url',
#  'lower',
#  'lower_',
#  'morph',
#  'n_lefts',
#  'n_rights',
#  'nbor',
#  'norm',
#  'norm_',
#  'orth',
#  'orth_',
#  'pos',
#  'pos_',
#  'prefix',
#  'prefix_',
#  'prob',
#  'rank',
#  'remove_extension',
#  'right_edge',
#  'rights',
#  'sent',
#  'sent_start',
#  'sentiment',
#  'set_extension',
#  'set_morph',
#  'shape',
#  'shape_',
#  'similarity',
#  'subtree',
#  'suffix',
#  'suffix_',
#  'tag',
#  'tag_',
#  'tensor',
#  'text',
#  'text_with_ws',
#  'vector',
#  'vector_norm',
#  'vocab',
#  'whitespace_']

# %%
type(tokern0)
# Out:
# spacy.tokens.token.Token

# %%
tokern0.is_alpha
# Out:
# True

# %%
token2=doc[2]
token2.text
# Out:
# 'two'

# %%
token2.like_num
# Out:
# True

# %%
for token in doc:
  print(token,"==>: ", token.i,
        "is_alpha:", token.is_alpha,
        "is_punct:", token.is_punct,
        "like_num:", token.like_num,
        "is_currency:",token.is_currency
  )
# Out:
# Tony ==>:  0 is_alpha: True is_punct: False like_num: False is_currency: False
# gave ==>:  1 is_alpha: True is_punct: False like_num: False is_currency: False
# two ==>:  2 is_alpha: True is_punct: False like_num: True is_currency: False
# $ ==>:  3 is_alpha: False is_punct: False like_num: False is_currency: True
# to ==>:  4 is_alpha: True is_punct: False like_num: False is_currency: False
# peter ==>:  5 is_alpha: True is_punct: False like_num: False is_currency: False
# . ==>:  6 is_alpha: False is_punct: True like_num: False is_currency: False

# %%
with open("students.txt") as f:
    text = f.readlines()
text
# Out:
# ['Dayton high school, 8th grade students information\n',
#  '==================================================\n',
#  '\n',
#  'Name\tbirth day   \temail\n',
#  '-----\t------------\t------\n',
#  'Virat   5 June, 1882    virat@kohli.com\n',
#  'Maria\t12 April, 2001  maria@sharapova.com\n',
#  'Serena  24 June, 1998   serena@williams.com \n',
#  'Joe      1 May, 1997    joe@root.com\n',
#  '\n',
#  '\n',
#  '\n']

# %%
text = " ".join(text)
text
# Out:
# 'Dayton high school, 8th grade students information\n ==================================================\n \n Name\tbirth day   \temail\n -----\t------------\t------\n Virat   5 June, 1882    virat@kohli.com\n Maria\t12 April, 2001  maria@sharapova.com\n Serena  24 June, 1998   serena@williams.com \n Joe      1 May, 1997    joe@root.com\n \n \n \n'

# %%
doc = nlp(text)
emails = []
for token in doc:
    if token.like_email:
        emails.append(token.text)
emails
# Out:
# ['virat@kohli.com',
#  'maria@sharapova.com',
#  'serena@williams.com',
#  'joe@root.com']

# %%
from spacy.symbols import ORTH

nlp = spacy.blank("en")
doc = nlp("gimme double cheese extra large healthy pizza")
tokens = [token.text for token in doc]
tokens
# Out:
# ['gimme', 'double', 'cheese', 'extra', 'large', 'healthy', 'pizza']

# %%
nlp.tokenizer.add_special_case("gimme", [
    {ORTH: "gim"},
    {ORTH: "me"},
])
doc = nlp("gimme double cheese extra large healthy pizza")
tokens = [token.text for token in doc]
tokens
# Out:
# ['gim', 'me', 'double', 'cheese', 'extra', 'large', 'healthy', 'pizza']

# %%
doc = nlp("Dr. Strange loves pav bhaji of mumbai. Hulk loves chat of delhi")
for sentence in doc.sents:
    print(sentence)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 2
#       1 doc = nlp("Dr. Strange loves pav bhaji of mumbai. Hulk loves chat of delhi")
# ----> 2 for sentence in doc.sents:
#       3     print(sentence)
#
# File c:\Users\taimo\AppData\Local\Programs\Python\Python311\Lib\site-packages\spacy\tokens\doc.pyx:926, in sents()
#
# ValueError: [E030] Sentence boundaries unset. You can add the 'sentencizer' component to the pipeline with: `nlp.add_pipe('sentencizer')`. Alternatively, add the dependency parser or sentence recognizer, or set sentence boundaries by setting `doc[i].is_sent_start`.

# %%
nlp.pipeline
# Out:
# []

# %%
nlp.add_pipe('sentencizer')

# %%
doc = nlp("Dr. Strange loves pav bhaji of mumbai. Hulk loves chat of delhi")
for sentence in doc.sents:
    print(sentence)
# Out:
# Dr. Strange loves pav bhaji of mumbai.
# Hulk loves chat of delhi

# %%
nlp.pipeline
# Out:
# [('sentencizer', <spacy.pipeline.sentencizer.Sentencizer at 0x236974f26d0>)]
