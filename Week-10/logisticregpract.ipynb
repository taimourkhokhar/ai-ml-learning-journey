# %%
import pandas as pd
df=pd.read_csv("HR_comma_sep.csv")
df.sample(10)
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 542                  0.77             0.91               5
# 2517                 0.55             0.63               5
# 4570                 0.66             0.90               3
# 7118                 0.85             0.67               3
# 280                  0.10             0.98               6
# 12990                0.79             0.61               4
# 8427                 0.55             0.51               3
# 4907                 0.62             0.49               3
# 3400                 0.98             0.60               2
# 2651                 0.73             0.81               3
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 542                     236                   5              0     1
# 2517                    184                   4              0     0
# 4570                    217                   4              0     0
# 7118                    267                   2              1     0
# 280                     268                   4              0     1
# 12990                   227                   2              0     0
# 8427                    192                   3              0     0
# 4907                    158                   2              0     0
# 3400                    249                   3              0     0
# 2651                    168                   2              0     0
#
#        promotion_last_5years   Department  salary
# 542                        0    marketing  medium
# 2517                       0    marketing  medium
# 4570                       0  product_mng  medium
# 7118                       0        sales     low
# 280                        0      support     low
# 12990                      1        sales    high
# 8427                       0   accounting  medium
# 4907                       0        sales     low
# 3400                       0    technical     low
# 2651                       0    technical  medium

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   Department             14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# 25%              156.000000            3.000000       0.000000      0.000000
# 50%              200.000000            3.000000       0.000000      0.000000
# 75%              245.000000            4.000000       0.000000      0.000000
# max              310.000000           10.000000       1.000000      1.000000
#
#        promotion_last_5years
# count           14999.000000
# mean                0.021268
# std                 0.144281
# min                 0.000000
# 25%                 0.000000
# 50%                 0.000000
# 75%                 0.000000
# max                 1.000000

# %%
df['left'].value_counts()
# Out:
# left
# 0    11428
# 1     3571
# Name: count, dtype: int64

# %%
pd.crosstab(df['salary'],df['left'])### checkig is low salary leave more
# Out:
# left       0     1
# salary
# high    1155    82
# low     5144  2172
# medium  5129  1317

# %%
df.groupby('left')['satisfaction_level'].mean()
# Out:
# left
# 0    0.666810
# 1    0.440098
# Name: satisfaction_level, dtype: float64

# %%
df.groupby('left')['average_montly_hours'].mean()
# Out:
# left
# 0    199.060203
# 1    207.419210
# Name: average_montly_hours, dtype: float64

# %%
pd.crosstab(df['promotion_last_5years'], df['left'])
# Out:
# left                       0     1
# promotion_last_5years
# 0                      11128  3552
# 1                        300    19

# %%
from matplotlib import pyplot as plg
# %matplotlib inline

plg.bar(df['left'],df['salary'])
# Out:
# <BarContainer object of 14999 artists>

# %%
plg.bar(df['left'],df['Department'])
