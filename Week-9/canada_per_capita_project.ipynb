# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

df=pd.read_csv("canada_per_capita_income.csv")
df.head()
# plt.xlabel("per capita income")
# plt.ylabel("year")
# plt.scatter(df.per_capita_income,df.year,color="red",marker="+")
# Out:
# Text(0, 0.5, 'year')
